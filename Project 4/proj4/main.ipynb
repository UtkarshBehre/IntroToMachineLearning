# %% [markdown]
# # **Project 4 - Q Learning**
#
# For this project, you will be tasked with both implementing and explaining key components of the Q-learning algorithm.
#
# All the code deliverables has to be provided within this notebook.
#
# # 1 - Packages
# Let's first import all the packages that you will need during this assignment.
#
# *
# [numpy](https://numpy.org/) - is the main package for scientific computing with Python
# *
# [matplotlib](https://matplotlib.org/) - is a plotting library
# *
# [gym](https://gym.openai.com/docs/) - Gym is a toolkit for developing and comparing reinforcement learning algorithms.
# *
# [gym.spaces](http://gym.openai.com/docs/) - Every environment comes with an action_space and an observation_space. These attributes are of type Space, and they describe the format of valid actions and observations.
# *
# [time](https://docs.python.org/3/library/time.html?highlight=time#module-time) - will be used to track how much time each computation takes
# *
# [copy](https://docs.python.org/3/library/copy.html) - A copy is sometimes needed so one can change one copy without changing the other.
# *
# [Threading](https://docs.python.org/3/library/threading.html) - This module constructs higher-level threading interfaces on top of the lower level thread module.
# *
# [Collections](https://docs.python.org/2/library/collections.html) - This module implements specialized container datatypes providing alternatives to Python’s general purpose built-in containers, dict, list, set, and tuple.

# %%
#######################################################################
# Authors:
# Nathan Margaglio (nathanmargaglio@gmail.com)                                                          
# Mihir Hemant Chauhan (mihirhem@buffalo.edu)                       
# Qian Cheng (qcheng2@buffalo.edu)                            
#######################################################################
import numpy as np
import matplotlib.pyplot as plt
import gym
import gym.spaces
import time
import copy
import threading
import time
import collections

# %% [markdown]
# ## Basic Environment
# Here we define our grid-world environment. No need to make any changes.

# %%
class GridEnvironment(gym.Env):
    metadata = { 'render.modes': ['human'] }
    
    def __init__(self, normalize=False, size=4):
        self.observation_space = gym.spaces.Box(0, size, (size,))
        self.action_space = gym.spaces.Discrete(4)
        self.max_timesteps = size*2 + 1
        self.normalize = normalize
        self.size = size

        # Generate State Transition Table
        self.transition_matrix = []
        for x in range(size + 1):
            state_x = []
            for y in range(size + 1):
                state_y = []
                for a in range(4):
                    one_hot = np.zeros(4)
                    one_hot[a] = 1
                    state_y.append(one_hot)
                state_x.append(state_y)
            self.transition_matrix.append(state_x)
        
    def transition_func(self, x, y, action, return_probs=False):
        probs = self.transition_matrix[x][y][action]
        if return_probs:
            return probs
        else:
            return np.random.choice(len(probs), p=probs)

    def _get_distance(self, x, y):
        return abs(x[0] - y[0]) + abs(x[1] - y[1])
        
    def reset(self):
        self.timestep = 0
        self.agent_pos = [0, 0]
        self.goal_pos = [self.size, self.size]
        self.state = np.zeros((self.size + 1, self.size + 1))
        self.state[tuple(self.agent_pos)] = 1
        self.state[tuple(self.goal_pos)] = 0.5
        self.prev_distance = self._get_distance(self.agent_pos, self.goal_pos)
        return np.array(self.agent_pos)/1.
    
    def step(self, action):
        action_taken = self.transition_func(self.agent_pos[0], self.agent_pos[1], action)
        self.state = np.random.choice(self.observation_space.shape[0])
        if action_taken == 0:
            self.agent_pos[0] += 1
        if action_taken == 1:
            self.agent_pos[0] -= 1
        if action_taken == 2:
            self.agent_pos[1] += 1
        if action_taken == 3:
            self.agent_pos[1] -= 1
          
        self.agent_pos = np.clip(self.agent_pos, 0, self.size)
        self.state = np.zeros((self.size + 1, self.size + 1))
        self.state[tuple(self.agent_pos)] = 1
        self.state[tuple(self.goal_pos)] = 0.5
        
        current_distance = self._get_distance(self.agent_pos, self.goal_pos)
        if current_distance < self.prev_distance:
            reward = 1
        elif current_distance > self.prev_distance:
            reward = -1
        else:
            reward = -1
        self.prev_distance = current_distance
        
        self.timestep += 1
        if self.timestep >= self.max_timesteps or current_distance == 0:
            done = True
        else:
            done = False
        info = {}
        
        obs = self.agent_pos
        if self.normalize:
            obs = obs/self.size
        return obs, reward, done, info
        
    def render(self, mode='human'):
        plt.imshow(self.state)

# %%
env = GridEnvironment()
obs = env.reset()
env.render()

# %% [markdown]
# ## Random Agent
# This runs the environment with a random agent that just takes random actions. Neither does he learn, nor remember anything. Try to run it!

# %%
class RandomAgent:
    def __init__(self, env):
        self.env = env
        self.observation_space = env.observation_space
        self.action_space = env.action_space

    def policy(self, observation):
        return np.random.choice(self.action_space.n)
        
    def step(self, observation, verbose=False):
        return self.policy(observation)

# %%
env = GridEnvironment(normalize=True)
agent = RandomAgent(env)

obs = env.reset()
done = False
agent.epsilon = 0
env.render()
plt.show()

while not done:
    action = agent.step(obs, verbose=True)
    obs, reward, done, info = env.step(action)
    env.render()
    plt.show()

# %% [markdown]
# ## Heuristic Agent
# This runs the environment with a heuristic agent. No need to make any changes. Try to run it!

# %%
class HeuristicAgent:
    def __init__(self, env):
        self.env = env
        self.observation_space = env.observation_space
        self.action_space = env.action_space

    def policy(self, observation):
        # 0 - down
        # 1 - up
        # 2 - right
        # 3 - left
        if (observation[0] < 1.):
            return 0
        if (observation[1] < 1.):
            return 2
        return 0
        
    def step(self, observation, verbose=False):
        if verbose:
            print(observation)
        return self.policy(observation)

# %%
env = GridEnvironment(normalize=True)
agent = HeuristicAgent(env)

obs = env.reset()
done = False
agent.epsilon = 0
env.render()
plt.show()

while not done:
    action = agent.step(obs, verbose=True)
    obs, reward, done, info = env.step(action)
    env.render()
    plt.show()
# Out:
# [0. 0.]
# [0.25 0.  ]
# [0.5 0. ]
# [0.75 0.  ]
# [1. 0.]
# [1.   0.25]
# [1.  0.5]
# [1.   0.75]

# %% [markdown]
# ## Tabular Q-Learning
# This is where you need to define policy and update Q tables.
# For policy.
#
# *
# [np.argmax](https://docs.scipy.org/doc/numpy/reference/generated/numpy.argmax.html) - Returns the indices of the maximum values along an axis.
#
# ### Epsilon
#
# Our agent will randomly select its action at first by a certain percentage, called ‘exploration rate’ or ‘epsilon’. This is because at first, it is better for the agent to try all kinds of things before it starts to see the patterns. When it is not deciding the action randomly, the agent will predict the reward value based on the current state and pick the action that will give the highest reward. We want our agent to decrease the number of random action, as it goes, so we indroduce an exponential-decay epsilon, that eventually will allow our agent to explore the evironment. \\
#
#
#
# ###  <font color='red'>Task 1: Implement policy function.</font>  <br>
# **Instructions:**
# - Our agent will randomly select its action at first by a certain percentage, called ‘exploration rate’ or ‘epsilon’. This is because at first, it is better for the agent to try all kinds of things before it starts to see the patterns. Select a random uniform number. If it's less than epsilon, return the random choice action space.
# - When it is not deciding the action randomly, the agent will predict the reward value based on the current state and pick the action that will give the highest reward.
# \begin{align} \notag
# \pi\left(s_{t}\right)=\underset{a \in A}{\operatorname{argmax}} Q_{\theta}\left(s_{t}, a\right)
# \end{align}
# - Return the policy
# - Please note, that the name for all the variables should start with <mark>self</mark>, thus </br>
#
# epsilon $\rightarrow$ self.epsilon </br>
# action_space $\rightarrow$ self.action_space
#
# ###  <font color='red'>Task 2: Update Q-table</font>  <br>
# **Instructions:**
#             \begin{align} \notag
#             Q^{n e w}\left(s_{t}, a_{t}\right) \leftarrow(1-\alpha) \cdot \underbrace{Q\left(s_{t}, a_{t}\right)}_{\text {old value }}+\underbrace{\alpha}_{\text {learning rate }} \cdot \overbrace{(\underbrace{r_{t}}_{\text {reward }} + \underbrace{\gamma}_{\text {discount factor }} \underbrace{\max _{a} Q\left(s_{t+1}, a\right)}_{a})}^{\text {learned value }}
#             \end{align}

# %%
class QLearningAgent:
    def __init__(self, env, epsilon=1.0, lr=0.1, gamma=0.9):
        self.env = env
        self.observation_space = env.observation_space
        self.action_space = env.action_space
        q_table_dim = env.observation_space.shape[0] + 1
        self.q_table = np.zeros((q_table_dim, q_table_dim, env.action_space.n))
        self.epsilon = epsilon
        self.lr = lr
        self.gamma = gamma

    def policy(self, observation):
        # 0 - down
        # 1 - up
        # 2 - right
        # 3 - left
        if (np.random.random_sample() < self.epsilon):
            return np.random.randint(4)
        else :
            return np.argmax(self.q_table[observation[0].astype(int),observation[1].astype(int)])
      # Code for policy (Task 1) (30 points)
        
    def step(self, observation):
        return self.policy(observation)
        
    def update(self, state, action, reward, next_state):
        state = state.astype(int)
        next_state = next_state.astype(int)
        self.q_table[state[0],state[1],action] += self.lr*(reward + self.gamma*np.max(self.q_table[state[0],state[1],action])) - self.q_table[state[0],state[1],action]
        # Code for updating Q Table (Task 2) (20 points)
        
    def set_epsilon(self, epsilon):
        self.epsilon = epsilon

# %% [markdown]
# ### Training
# ### Environment
# First, we initialize our environment.  The environment, loosely structured like [OpenAI's Gym Environments](https://gym.openai.com/), has three main methods: `reset`, `step` and `render`. You'll only need `reset` and `step` here.
#
# - When we call **reset**, we initialize the environment with a fresh episode. This allows us to effectively run through episodes (only needing to call reset at the beginning of an episode), but, more importantly, `reset()` returns the environment's initial state.
#
# - The **step** method accepts an action as a parameter (which, for this example, is an integer in [0, 3]), processes the action, and returns the new state, the reward for performing the action, and a boolean indicating if the run is over.
#
# ### Agent
# When we initialize the agent, we must pass both a `environment` into QLearningAgent function.
# ###  <font color='red'>Task 3: Implement the training algorithm</font>  <br>
# **Instructions:**
# - After initialization, pass the initial state to obs. Then check if it's already done. If done = False, you'll keep going. While it's not done, you'll need to update `state`, `action`,`reward` and `next_state`. You can get action by `step` the current state on agent. Use `copy` to record the current state. `step` the current action on environment to return the new state, the reward for performing the action, a boolean indicating if the run is over and some other information. Add the new reward on the total rewards. Use `copy` to save the new state returned by `step`. Update the `state`, `action`, `reward`, `next_state` of agent.

# %%
env = GridEnvironment() # note: we do not normalize
agent = QLearningAgent(env, epsilon = 1.0, lr=0.6, gamma = 0.8)
episodes = 1500 # number of games we want the agent to play
#delta_epsilon = agent.epsilon/episodes
decay = 0.9963
total_rewards = []
epsilons = [agent.epsilon]

state = env.reset()
env.render()
plt.show()

for episode in range(episodes):
    state = env.reset()
    reward_every_episode = 0
    done = False

    while not done:
        cur_state = copy.deepcopy(state)
        action = agent.step(state)
        state, reward, done, info = env.step(action)
        agent.update(cur_state, action, reward, state)
        reward_every_episode += reward 
        #env.render()
        if done:
            break
    new_epsilon = agent.epsilon * decay
    agent.set_epsilon(new_epsilon)
    epsilons.append(new_epsilon)
    total_rewards.append(reward_every_episode)
    print("Episode: ", episode, "Total reward: ", reward_every_episode)
# for ref
# 0 - down
# 1 - up
# 2 - right
# 3 - left
# Training Process (Task 3) (20 points)
# Out:
# Episode:  0 Total reward:  -3
# Episode:  1 Total reward:  3
# Episode:  2 Total reward:  -1
# Episode:  3 Total reward:  1
# Episode:  4 Total reward:  -5
# Episode:  5 Total reward:  -5
# Episode:  6 Total reward:  -1
# Episode:  7 Total reward:  3
# Episode:  8 Total reward:  -7
# Episode:  9 Total reward:  -3
# Episode:  10 Total reward:  -1
# Episode:  11 Total reward:  -5
# Episode:  12 Total reward:  3
# Episode:  13 Total reward:  -1
# Episode:  14 Total reward:  5
# Episode:  15 Total reward:  -3
# Episode:  16 Total reward:  -1
# Episode:  17 Total reward:  -1
# Episode:  18 Total reward:  1
# Episode:  19 Total reward:  -3
# Episode:  20 Total reward:  3
# Episode:  21 Total reward:  1
# Episode:  22 Total reward:  -1
# Episode:  23 Total reward:  1
# Episode:  24 Total reward:  1
# Episode:  25 Total reward:  5
# Episode:  26 Total reward:  1
# Episode:  27 Total reward:  -5
# Episode:  28 Total reward:  -3
# Episode:  29 Total reward:  1
# Episode:  30 Total reward:  1
# Episode:  31 Total reward:  -1
# Episode:  32 Total reward:  5
# Episode:  33 Total reward:  3
# Episode:  34 Total reward:  1
# Episode:  35 Total reward:  3
# Episode:  36 Total reward:  1
# Episode:  37 Total reward:  -1
# Episode:  38 Total reward:  1
# Episode:  39 Total reward:  1
# Episode:  40 Total reward:  3
# Episode:  41 Total reward:  3
# Episode:  42 Total reward:  3
# Episode:  43 Total reward:  -1
# Episode:  44 Total reward:  7
# Episode:  45 Total reward:  -1
# Episode:  46 Total reward:  -1
# Episode:  47 Total reward:  -1
# Episode:  48 Total reward:  -1
# Episode:  49 Total reward:  -3
# Episode:  50 Total reward:  -5
# Episode:  51 Total reward:  -3
# Episode:  52 Total reward:  -1
# Episode:  53 Total reward:  -3
# Episode:  54 Total reward:  -3
# Episode:  55 Total reward:  1
# Episode:  56 Total reward:  -1
# Episode:  57 Total reward:  3
# Episode:  58 Total reward:  -1
# Episode:  59 Total reward:  -1
# Episode:  60 Total reward:  3
# Episode:  61 Total reward:  3
# Episode:  62 Total reward:  1
# Episode:  63 Total reward:  7
# Episode:  64 Total reward:  3
# Episode:  65 Total reward:  -1
# Episode:  66 Total reward:  7
# Episode:  67 Total reward:  5
# Episode:  68 Total reward:  -3
# Episode:  69 Total reward:  -1
# Episode:  70 Total reward:  3
# Episode:  71 Total reward:  -5
# Episode:  72 Total reward:  3
# Episode:  73 Total reward:  -3
# Episode:  74 Total reward:  1
# Episode:  75 Total reward:  3
# Episode:  76 Total reward:  3
# Episode:  77 Total reward:  -3
# Episode:  78 Total reward:  -1
# Episode:  79 Total reward:  1
# Episode:  80 Total reward:  -1
# Episode:  81 Total reward:  -3
# Episode:  82 Total reward:  -1
# Episode:  83 Total reward:  5
# Episode:  84 Total reward:  -1
# Episode:  85 Total reward:  5
# Episode:  86 Total reward:  -3
# Episode:  87 Total reward:  1
# Episode:  88 Total reward:  -3
# Episode:  89 Total reward:  1
# Episode:  90 Total reward:  1
# Episode:  91 Total reward:  -5
# Episode:  92 Total reward:  3
# Episode:  93 Total reward:  -1
# Episode:  94 Total reward:  -1
# Episode:  95 Total reward:  1
# Episode:  96 Total reward:  -3
# Episode:  97 Total reward:  1
# Episode:  98 Total reward:  3
# Episode:  99 Total reward:  1
# Episode:  100 Total reward:  -5
# Episode:  101 Total reward:  1
# Episode:  102 Total reward:  1
# Episode:  103 Total reward:  3
# Episode:  104 Total reward:  -1
# Episode:  105 Total reward:  -3
# Episode:  106 Total reward:  -1
# Episode:  107 Total reward:  3
# Episode:  108 Total reward:  1
# Episode:  109 Total reward:  -1
# Episode:  110 Total reward:  3
# Episode:  111 Total reward:  -3
# Episode:  112 Total reward:  3
# Episode:  113 Total reward:  -1
# Episode:  114 Total reward:  -1
# Episode:  115 Total reward:  1
# Episode:  116 Total reward:  1
# Episode:  117 Total reward:  1
# Episode:  118 Total reward:  -1
# Episode:  119 Total reward:  1
# Episode:  120 Total reward:  -3
# Episode:  121 Total reward:  3
# Episode:  122 Total reward:  5
# Episode:  123 Total reward:  5
# Episode:  124 Total reward:  -1
# Episode:  125 Total reward:  5
# Episode:  126 Total reward:  -3
# Episode:  127 Total reward:  -3
# Episode:  128 Total reward:  -1
# Episode:  129 Total reward:  1
# Episode:  130 Total reward:  1
# Episode:  131 Total reward:  -3
# Episode:  132 Total reward:  -1
# Episode:  133 Total reward:  -5
# Episode:  134 Total reward:  3
# Episode:  135 Total reward:  1
# Episode:  136 Total reward:  -1
# Episode:  137 Total reward:  -3
# Episode:  138 Total reward:  1
# Episode:  139 Total reward:  5
# Episode:  140 Total reward:  -1
# Episode:  141 Total reward:  5
# Episode:  142 Total reward:  3
# Episode:  143 Total reward:  5
# Episode:  144 Total reward:  5
# Episode:  145 Total reward:  1
# Episode:  146 Total reward:  3
# Episode:  147 Total reward:  -7
# Episode:  148 Total reward:  1
# Episode:  149 Total reward:  -3
# Episode:  150 Total reward:  -1
# Episode:  151 Total reward:  1
# Episode:  152 Total reward:  1
# Episode:  153 Total reward:  1
# Episode:  154 Total reward:  1
# Episode:  155 Total reward:  -5
# Episode:  156 Total reward:  1
# Episode:  157 Total reward:  5
# Episode:  158 Total reward:  1
# Episode:  159 Total reward:  5
# Episode:  160 Total reward:  5
# Episode:  161 Total reward:  1
# Episode:  162 Total reward:  -1
# Episode:  163 Total reward:  -1
# Episode:  164 Total reward:  -1
# Episode:  165 Total reward:  -5
# Episode:  166 Total reward:  3
# Episode:  167 Total reward:  -1
# Episode:  168 Total reward:  1
# Episode:  169 Total reward:  1
# Episode:  170 Total reward:  -1
# Episode:  171 Total reward:  -3
# Episode:  172 Total reward:  5
# Episode:  173 Total reward:  1
# Episode:  174 Total reward:  -5
# Episode:  175 Total reward:  -3
# Episode:  176 Total reward:  -3
# Episode:  177 Total reward:  -5
# Episode:  178 Total reward:  3
# Episode:  179 Total reward:  -3
# Episode:  180 Total reward:  3
# Episode:  181 Total reward:  -1
# Episode:  182 Total reward:  1
# Episode:  183 Total reward:  1
# Episode:  184 Total reward:  1
# Episode:  185 Total reward:  3
# Episode:  186 Total reward:  3
# Episode:  187 Total reward:  3
# Episode:  188 Total reward:  -3
# Episode:  189 Total reward:  1
# Episode:  190 Total reward:  -3
# Episode:  191 Total reward:  3
# Episode:  192 Total reward:  1
# Episode:  193 Total reward:  -1
# Episode:  194 Total reward:  1
# Episode:  195 Total reward:  -5
# Episode:  196 Total reward:  3
# Episode:  197 Total reward:  -1
# Episode:  198 Total reward:  -3
# Episode:  199 Total reward:  1
# Episode:  200 Total reward:  -1
# Episode:  201 Total reward:  1
# Episode:  202 Total reward:  1
# Episode:  203 Total reward:  3
# Episode:  204 Total reward:  -3
# Episode:  205 Total reward:  1
# Episode:  206 Total reward:  -1
# Episode:  207 Total reward:  1
# Episode:  208 Total reward:  -1
# Episode:  209 Total reward:  3
# Episode:  210 Total reward:  -1
# Episode:  211 Total reward:  -1
# Episode:  212 Total reward:  -1
# Episode:  213 Total reward:  -3
# Episode:  214 Total reward:  3
# Episode:  215 Total reward:  3
# Episode:  216 Total reward:  3
# Episode:  217 Total reward:  3
# Episode:  218 Total reward:  1
# Episode:  219 Total reward:  1
# Episode:  220 Total reward:  -1
# Episode:  221 Total reward:  -1
# Episode:  222 Total reward:  3
# Episode:  223 Total reward:  -5
# Episode:  224 Total reward:  3
# Episode:  225 Total reward:  3
# Episode:  226 Total reward:  -3
# Episode:  227 Total reward:  5
# Episode:  228 Total reward:  1
# Episode:  229 Total reward:  1
# Episode:  230 Total reward:  1
# Episode:  231 Total reward:  3
# Episode:  232 Total reward:  3
# Episode:  233 Total reward:  1
# Episode:  234 Total reward:  1
# Episode:  235 Total reward:  1
# Episode:  236 Total reward:  5
# Episode:  237 Total reward:  1
# Episode:  238 Total reward:  -3
# Episode:  239 Total reward:  1
# Episode:  240 Total reward:  3
# Episode:  241 Total reward:  1
# Episode:  242 Total reward:  -1
# Episode:  243 Total reward:  -1
# Episode:  244 Total reward:  -1
# Episode:  245 Total reward:  -1
# Episode:  246 Total reward:  3
# Episode:  247 Total reward:  3
# Episode:  248 Total reward:  3
# Episode:  249 Total reward:  3
# Episode:  250 Total reward:  -5
# Episode:  251 Total reward:  1
# Episode:  252 Total reward:  -7
# Episode:  253 Total reward:  3
# Episode:  254 Total reward:  -1
# Episode:  255 Total reward:  3
# Episode:  256 Total reward:  -3
# Episode:  257 Total reward:  1
# Episode:  258 Total reward:  5
# Episode:  259 Total reward:  -1
# Episode:  260 Total reward:  1
# Episode:  261 Total reward:  -1
# Episode:  262 Total reward:  -1
# Episode:  263 Total reward:  3
# Episode:  264 Total reward:  7
# Episode:  265 Total reward:  1
# Episode:  266 Total reward:  1
# Episode:  267 Total reward:  1
# Episode:  268 Total reward:  1
# Episode:  269 Total reward:  -1
# Episode:  270 Total reward:  3
# Episode:  271 Total reward:  -3
# Episode:  272 Total reward:  5
# Episode:  273 Total reward:  1
# Episode:  274 Total reward:  1
# Episode:  275 Total reward:  7
# Episode:  276 Total reward:  -1
# Episode:  277 Total reward:  -3
# Episode:  278 Total reward:  7
# Episode:  279 Total reward:  -3
# Episode:  280 Total reward:  -1
# Episode:  281 Total reward:  -1
# Episode:  282 Total reward:  -1
# Episode:  283 Total reward:  -1
# Episode:  284 Total reward:  -3
# Episode:  285 Total reward:  -1
# Episode:  286 Total reward:  -1
# Episode:  287 Total reward:  -1
# Episode:  288 Total reward:  1
# Episode:  289 Total reward:  1
# Episode:  290 Total reward:  1
# Episode:  291 Total reward:  -1
# Episode:  292 Total reward:  3
# Episode:  293 Total reward:  -5
# Episode:  294 Total reward:  3
# Episode:  295 Total reward:  1
# Episode:  296 Total reward:  1
# Episode:  297 Total reward:  5
# Episode:  298 Total reward:  -3
# Episode:  299 Total reward:  1
# Episode:  300 Total reward:  1
# Episode:  301 Total reward:  3
# Episode:  302 Total reward:  -1
# Episode:  303 Total reward:  1
# Episode:  304 Total reward:  1
# Episode:  305 Total reward:  -1
# Episode:  306 Total reward:  -1
# Episode:  307 Total reward:  -3
# Episode:  308 Total reward:  -3
# Episode:  309 Total reward:  1
# Episode:  310 Total reward:  -7
# Episode:  311 Total reward:  5
# Episode:  312 Total reward:  -3
# Episode:  313 Total reward:  -1
# Episode:  314 Total reward:  1
# Episode:  315 Total reward:  -1
# Episode:  316 Total reward:  3
# Episode:  317 Total reward:  3
# Episode:  318 Total reward:  -3
# Episode:  319 Total reward:  3
# Episode:  320 Total reward:  -1
# Episode:  321 Total reward:  -5
# Episode:  322 Total reward:  3
# Episode:  323 Total reward:  3
# Episode:  324 Total reward:  -3
# Episode:  325 Total reward:  3
# Episode:  326 Total reward:  1
# Episode:  327 Total reward:  -7
# Episode:  328 Total reward:  3
# Episode:  329 Total reward:  -3
# Episode:  330 Total reward:  1
# Episode:  331 Total reward:  -1
# Episode:  332 Total reward:  -7
# Episode:  333 Total reward:  -1
# Episode:  334 Total reward:  -1
# Episode:  335 Total reward:  -1
# Episode:  336 Total reward:  1
# Episode:  337 Total reward:  1
# Episode:  338 Total reward:  1
# Episode:  339 Total reward:  -1
# Episode:  340 Total reward:  -5
# Episode:  341 Total reward:  -1
# Episode:  342 Total reward:  -3
# Episode:  343 Total reward:  5
# Episode:  344 Total reward:  -3
# Episode:  345 Total reward:  -1
# Episode:  346 Total reward:  -1
# Episode:  347 Total reward:  5
# Episode:  348 Total reward:  1
# Episode:  349 Total reward:  -5
# Episode:  350 Total reward:  -1
# Episode:  351 Total reward:  -1
# Episode:  352 Total reward:  1
# Episode:  353 Total reward:  -1
# Episode:  354 Total reward:  1
# Episode:  355 Total reward:  -1
# Episode:  356 Total reward:  1
# Episode:  357 Total reward:  -3
# Episode:  358 Total reward:  5
# Episode:  359 Total reward:  -1
# Episode:  360 Total reward:  1
# Episode:  361 Total reward:  -1
# Episode:  362 Total reward:  -7
# Episode:  363 Total reward:  1
# Episode:  364 Total reward:  1
# Episode:  365 Total reward:  -1
# Episode:  366 Total reward:  -5
# Episode:  367 Total reward:  -5
# Episode:  368 Total reward:  -1
# Episode:  369 Total reward:  -1
# Episode:  370 Total reward:  -1
# Episode:  371 Total reward:  -1
# Episode:  372 Total reward:  -3
# Episode:  373 Total reward:  -1
# Episode:  374 Total reward:  -1
# Episode:  375 Total reward:  -1
# Episode:  376 Total reward:  1
# Episode:  377 Total reward:  3
# Episode:  378 Total reward:  1
# Episode:  379 Total reward:  -1
# Episode:  380 Total reward:  3
# Episode:  381 Total reward:  -1
# Episode:  382 Total reward:  -1
# Episode:  383 Total reward:  1
# Episode:  384 Total reward:  1
# Episode:  385 Total reward:  -1
# Episode:  386 Total reward:  -1
# Episode:  387 Total reward:  5
# Episode:  388 Total reward:  1
# Episode:  389 Total reward:  -5
# Episode:  390 Total reward:  3
# Episode:  391 Total reward:  -1
# Episode:  392 Total reward:  -1
# Episode:  393 Total reward:  -1
# Episode:  394 Total reward:  3
# Episode:  395 Total reward:  -5
# Episode:  396 Total reward:  -1
# Episode:  397 Total reward:  3
# Episode:  398 Total reward:  -1
# Episode:  399 Total reward:  5
# Episode:  400 Total reward:  1
# Episode:  401 Total reward:  1
# Episode:  402 Total reward:  1
# Episode:  403 Total reward:  1
# Episode:  404 Total reward:  -3
# Episode:  405 Total reward:  -1
# Episode:  406 Total reward:  3
# Episode:  407 Total reward:  1
# Episode:  408 Total reward:  -1
# Episode:  409 Total reward:  1
# Episode:  410 Total reward:  -1
# Episode:  411 Total reward:  -1
# Episode:  412 Total reward:  -1
# Episode:  413 Total reward:  -5
# Episode:  414 Total reward:  1
# Episode:  415 Total reward:  1
# Episode:  416 Total reward:  -3
# Episode:  417 Total reward:  -1
# Episode:  418 Total reward:  -5
# Episode:  419 Total reward:  -1
# Episode:  420 Total reward:  3
# Episode:  421 Total reward:  -3
# Episode:  422 Total reward:  1
# Episode:  423 Total reward:  -5
# Episode:  424 Total reward:  -1
# Episode:  425 Total reward:  1
# Episode:  426 Total reward:  -1
# Episode:  427 Total reward:  -3
# Episode:  428 Total reward:  1
# Episode:  429 Total reward:  5
# Episode:  430 Total reward:  -3
# Episode:  431 Total reward:  5
# Episode:  432 Total reward:  -3
# Episode:  433 Total reward:  1
# Episode:  434 Total reward:  1
# Episode:  435 Total reward:  3
# Episode:  436 Total reward:  -3
# Episode:  437 Total reward:  -1
# Episode:  438 Total reward:  5
# Episode:  439 Total reward:  -1
# Episode:  440 Total reward:  3
# Episode:  441 Total reward:  -3
# Episode:  442 Total reward:  -1
# Episode:  443 Total reward:  1
# Episode:  444 Total reward:  1
# Episode:  445 Total reward:  5
# Episode:  446 Total reward:  3
# Episode:  447 Total reward:  -3
# Episode:  448 Total reward:  5
# Episode:  449 Total reward:  1
# Episode:  450 Total reward:  1
# Episode:  451 Total reward:  -1
# Episode:  452 Total reward:  -1
# Episode:  453 Total reward:  -1
# Episode:  454 Total reward:  -1
# Episode:  455 Total reward:  1
# Episode:  456 Total reward:  3
# Episode:  457 Total reward:  -3
# Episode:  458 Total reward:  -1
# Episode:  459 Total reward:  5
# Episode:  460 Total reward:  -3
# Episode:  461 Total reward:  -1
# Episode:  462 Total reward:  -3
# Episode:  463 Total reward:  -1
# Episode:  464 Total reward:  1
# Episode:  465 Total reward:  -1
# Episode:  466 Total reward:  5
# Episode:  467 Total reward:  -1
# Episode:  468 Total reward:  3
# Episode:  469 Total reward:  3
# Episode:  470 Total reward:  1
# Episode:  471 Total reward:  -3
# Episode:  472 Total reward:  1
# Episode:  473 Total reward:  -3
# Episode:  474 Total reward:  -1
# Episode:  475 Total reward:  1
# Episode:  476 Total reward:  -5
# Episode:  477 Total reward:  -1
# Episode:  478 Total reward:  -1
# Episode:  479 Total reward:  1
# Episode:  480 Total reward:  -7
# Episode:  481 Total reward:  1
# Episode:  482 Total reward:  1
# Episode:  483 Total reward:  3
# Episode:  484 Total reward:  -1
# Episode:  485 Total reward:  3
# Episode:  486 Total reward:  1
# Episode:  487 Total reward:  -1
# Episode:  488 Total reward:  1
# Episode:  489 Total reward:  -3
# Episode:  490 Total reward:  -1
# Episode:  491 Total reward:  -5
# Episode:  492 Total reward:  -5
# Episode:  493 Total reward:  -5
# Episode:  494 Total reward:  1
# Episode:  495 Total reward:  3
# Episode:  496 Total reward:  7
# Episode:  497 Total reward:  -3
# Episode:  498 Total reward:  -1
# Episode:  499 Total reward:  3
# Episode:  500 Total reward:  -1
# Episode:  501 Total reward:  -1
# Episode:  502 Total reward:  -3
# Episode:  503 Total reward:  3
# Episode:  504 Total reward:  5
# Episode:  505 Total reward:  1
# Episode:  506 Total reward:  5
# Episode:  507 Total reward:  -1
# Episode:  508 Total reward:  -1
# Episode:  509 Total reward:  -1
# Episode:  510 Total reward:  3
# Episode:  511 Total reward:  1
# Episode:  512 Total reward:  3
# Episode:  513 Total reward:  -3
# Episode:  514 Total reward:  -1
# Episode:  515 Total reward:  -1
# Episode:  516 Total reward:  1
# Episode:  517 Total reward:  3
# Episode:  518 Total reward:  -1
# Episode:  519 Total reward:  -1
# Episode:  520 Total reward:  -3
# Episode:  521 Total reward:  -3
# Episode:  522 Total reward:  -7
# Episode:  523 Total reward:  -1
# Episode:  524 Total reward:  3
# Episode:  525 Total reward:  3
# Episode:  526 Total reward:  -1
# Episode:  527 Total reward:  3
# Episode:  528 Total reward:  -3
# Episode:  529 Total reward:  -3
# Episode:  530 Total reward:  3
# Episode:  531 Total reward:  -1
# Episode:  532 Total reward:  -7
# Episode:  533 Total reward:  -1
# Episode:  534 Total reward:  1
# Episode:  535 Total reward:  5
# Episode:  536 Total reward:  -1
# Episode:  537 Total reward:  1
# Episode:  538 Total reward:  1
# Episode:  539 Total reward:  3
# Episode:  540 Total reward:  -1
# Episode:  541 Total reward:  -1
# Episode:  542 Total reward:  -3
# Episode:  543 Total reward:  -1
# Episode:  544 Total reward:  1
# Episode:  545 Total reward:  -1
# Episode:  546 Total reward:  1
# Episode:  547 Total reward:  1
# Episode:  548 Total reward:  3
# Episode:  549 Total reward:  3
# Episode:  550 Total reward:  -1
# Episode:  551 Total reward:  1
# Episode:  552 Total reward:  -3
# Episode:  553 Total reward:  -3
# Episode:  554 Total reward:  -5
# Episode:  555 Total reward:  -1
# Episode:  556 Total reward:  -1
# Episode:  557 Total reward:  1
# Episode:  558 Total reward:  -5
# Episode:  559 Total reward:  1
# Episode:  560 Total reward:  1
# Episode:  561 Total reward:  1
# Episode:  562 Total reward:  1
# Episode:  563 Total reward:  -3
# Episode:  564 Total reward:  -3
# Episode:  565 Total reward:  -5
# Episode:  566 Total reward:  3
# Episode:  567 Total reward:  -3
# Episode:  568 Total reward:  -7
# Episode:  569 Total reward:  -5
# Episode:  570 Total reward:  -3
# Episode:  571 Total reward:  8
# Episode:  572 Total reward:  -3
# Episode:  573 Total reward:  -1
# Episode:  574 Total reward:  1
# Episode:  575 Total reward:  3
# Episode:  576 Total reward:  1
# Episode:  577 Total reward:  -1
# Episode:  578 Total reward:  1
# Episode:  579 Total reward:  -3
# Episode:  580 Total reward:  -9
# Episode:  581 Total reward:  -1
# Episode:  582 Total reward:  1
# Episode:  583 Total reward:  1
# Episode:  584 Total reward:  -3
# Episode:  585 Total reward:  -1
# Episode:  586 Total reward:  3
# Episode:  587 Total reward:  -3
# Episode:  588 Total reward:  -5
# Episode:  589 Total reward:  -1
# Episode:  590 Total reward:  -1
# Episode:  591 Total reward:  1
# Episode:  592 Total reward:  -5
# Episode:  593 Total reward:  1
# Episode:  594 Total reward:  -3
# Episode:  595 Total reward:  -1
# Episode:  596 Total reward:  7
# Episode:  597 Total reward:  1
# Episode:  598 Total reward:  -1
# Episode:  599 Total reward:  -5
# Episode:  600 Total reward:  1
# Episode:  601 Total reward:  -1
# Episode:  602 Total reward:  1
# Episode:  603 Total reward:  5
# Episode:  604 Total reward:  1
# Episode:  605 Total reward:  1
# Episode:  606 Total reward:  1
# Episode:  607 Total reward:  1
# Episode:  608 Total reward:  5
# Episode:  609 Total reward:  -5
# Episode:  610 Total reward:  -1
# Episode:  611 Total reward:  -1
# Episode:  612 Total reward:  3
# Episode:  613 Total reward:  -3
# Episode:  614 Total reward:  -1
# Episode:  615 Total reward:  3
# Episode:  616 Total reward:  3
# Episode:  617 Total reward:  -5
# Episode:  618 Total reward:  5
# Episode:  619 Total reward:  -3
# Episode:  620 Total reward:  -3
# Episode:  621 Total reward:  1
# Episode:  622 Total reward:  3
# Episode:  623 Total reward:  -3
# Episode:  624 Total reward:  3
# Episode:  625 Total reward:  1
# Episode:  626 Total reward:  -1
# Episode:  627 Total reward:  5
# Episode:  628 Total reward:  -5
# Episode:  629 Total reward:  3
# Episode:  630 Total reward:  -3
# Episode:  631 Total reward:  1
# Episode:  632 Total reward:  -3
# Episode:  633 Total reward:  3
# Episode:  634 Total reward:  -3
# Episode:  635 Total reward:  5
# Episode:  636 Total reward:  -1
# Episode:  637 Total reward:  -1
# Episode:  638 Total reward:  1
# Episode:  639 Total reward:  1
# Episode:  640 Total reward:  -1
# Episode:  641 Total reward:  -3
# Episode:  642 Total reward:  3
# Episode:  643 Total reward:  1
# Episode:  644 Total reward:  5
# Episode:  645 Total reward:  1
# Episode:  646 Total reward:  1
# Episode:  647 Total reward:  3
# Episode:  648 Total reward:  -3
# Episode:  649 Total reward:  -1
# Episode:  650 Total reward:  -1
# Episode:  651 Total reward:  -1
# Episode:  652 Total reward:  -1
# Episode:  653 Total reward:  3
# Episode:  654 Total reward:  -1
# Episode:  655 Total reward:  1
# Episode:  656 Total reward:  -1
# Episode:  657 Total reward:  -1
# Episode:  658 Total reward:  1
# Episode:  659 Total reward:  -3
# Episode:  660 Total reward:  -3
# Episode:  661 Total reward:  -3
# Episode:  662 Total reward:  -1
# Episode:  663 Total reward:  5
# Episode:  664 Total reward:  -3
# Episode:  665 Total reward:  1
# Episode:  666 Total reward:  3
# Episode:  667 Total reward:  -1
# Episode:  668 Total reward:  -5
# Episode:  669 Total reward:  -1
# Episode:  670 Total reward:  -1
# Episode:  671 Total reward:  5
# Episode:  672 Total reward:  -1
# Episode:  673 Total reward:  1
# Episode:  674 Total reward:  5
# Episode:  675 Total reward:  -1
# Episode:  676 Total reward:  -1
# Episode:  677 Total reward:  -1
# Episode:  678 Total reward:  -1
# Episode:  679 Total reward:  1
# Episode:  680 Total reward:  -5
# Episode:  681 Total reward:  5
# Episode:  682 Total reward:  -3
# Episode:  683 Total reward:  -3
# Episode:  684 Total reward:  -3
# Episode:  685 Total reward:  -1
# Episode:  686 Total reward:  -5
# Episode:  687 Total reward:  -1
# Episode:  688 Total reward:  -1
# Episode:  689 Total reward:  1
# Episode:  690 Total reward:  3
# Episode:  691 Total reward:  -1
# Episode:  692 Total reward:  -1
# Episode:  693 Total reward:  3
# Episode:  694 Total reward:  -3
# Episode:  695 Total reward:  -5
# Episode:  696 Total reward:  1
# Episode:  697 Total reward:  -1
# Episode:  698 Total reward:  -1
# Episode:  699 Total reward:  -1
# Episode:  700 Total reward:  -1
# Episode:  701 Total reward:  -5
# Episode:  702 Total reward:  -3
# Episode:  703 Total reward:  -1
# Episode:  704 Total reward:  1
# Episode:  705 Total reward:  5
# Episode:  706 Total reward:  -3
# Episode:  707 Total reward:  -3
# Episode:  708 Total reward:  -1
# Episode:  709 Total reward:  -1
# Episode:  710 Total reward:  3
# Episode:  711 Total reward:  -1
# Episode:  712 Total reward:  3
# Episode:  713 Total reward:  5
# Episode:  714 Total reward:  1
# Episode:  715 Total reward:  1
# Episode:  716 Total reward:  -1
# Episode:  717 Total reward:  1
# Episode:  718 Total reward:  3
# Episode:  719 Total reward:  -3
# Episode:  720 Total reward:  -3
# Episode:  721 Total reward:  1
# Episode:  722 Total reward:  -5
# Episode:  723 Total reward:  -1
# Episode:  724 Total reward:  1
# Episode:  725 Total reward:  -1
# Episode:  726 Total reward:  -1
# Episode:  727 Total reward:  -1
# Episode:  728 Total reward:  -1
# Episode:  729 Total reward:  1
# Episode:  730 Total reward:  7
# Episode:  731 Total reward:  -3
# Episode:  732 Total reward:  -1
# Episode:  733 Total reward:  -1
# Episode:  734 Total reward:  -1
# Episode:  735 Total reward:  1
# Episode:  736 Total reward:  3
# Episode:  737 Total reward:  -1
# Episode:  738 Total reward:  -1
# Episode:  739 Total reward:  1
# Episode:  740 Total reward:  1
# Episode:  741 Total reward:  1
# Episode:  742 Total reward:  -3
# Episode:  743 Total reward:  1
# Episode:  744 Total reward:  3
# Episode:  745 Total reward:  1
# Episode:  746 Total reward:  -1
# Episode:  747 Total reward:  -3
# Episode:  748 Total reward:  -1
# Episode:  749 Total reward:  3
# Episode:  750 Total reward:  5
# Episode:  751 Total reward:  3
# Episode:  752 Total reward:  1
# Episode:  753 Total reward:  -5
# Episode:  754 Total reward:  -1
# Episode:  755 Total reward:  -1
# Episode:  756 Total reward:  -1
# Episode:  757 Total reward:  -3
# Episode:  758 Total reward:  -1
# Episode:  759 Total reward:  3
# Episode:  760 Total reward:  -5
# Episode:  761 Total reward:  -1
# Episode:  762 Total reward:  -5
# Episode:  763 Total reward:  -3
# Episode:  764 Total reward:  7
# Episode:  765 Total reward:  5
# Episode:  766 Total reward:  -1
# Episode:  767 Total reward:  -1
# Episode:  768 Total reward:  1
# Episode:  769 Total reward:  1
# Episode:  770 Total reward:  -3
# Episode:  771 Total reward:  -1
# Episode:  772 Total reward:  5
# Episode:  773 Total reward:  3
# Episode:  774 Total reward:  1
# Episode:  775 Total reward:  -1
# Episode:  776 Total reward:  3
# Episode:  777 Total reward:  -5
# Episode:  778 Total reward:  -1
# Episode:  779 Total reward:  -5
# Episode:  780 Total reward:  3
# Episode:  781 Total reward:  3
# Episode:  782 Total reward:  -1
# Episode:  783 Total reward:  7
# Episode:  784 Total reward:  3
# Episode:  785 Total reward:  -1
# Episode:  786 Total reward:  3
# Episode:  787 Total reward:  -3
# Episode:  788 Total reward:  5
# Episode:  789 Total reward:  3
# Episode:  790 Total reward:  1
# Episode:  791 Total reward:  -5
# Episode:  792 Total reward:  3
# Episode:  793 Total reward:  -1
# Episode:  794 Total reward:  -3
# Episode:  795 Total reward:  -1
# Episode:  796 Total reward:  -1
# Episode:  797 Total reward:  3
# Episode:  798 Total reward:  1
# Episode:  799 Total reward:  -3
# Episode:  800 Total reward:  3
# Episode:  801 Total reward:  -3
# Episode:  802 Total reward:  -3
# Episode:  803 Total reward:  3
# Episode:  804 Total reward:  3
# Episode:  805 Total reward:  3
# Episode:  806 Total reward:  3
# Episode:  807 Total reward:  -1
# Episode:  808 Total reward:  3
# Episode:  809 Total reward:  1
# Episode:  810 Total reward:  1
# Episode:  811 Total reward:  3
# Episode:  812 Total reward:  -3
# Episode:  813 Total reward:  -1
# Episode:  814 Total reward:  -1
# Episode:  815 Total reward:  -1
# Episode:  816 Total reward:  -7
# Episode:  817 Total reward:  -1
# Episode:  818 Total reward:  1
# Episode:  819 Total reward:  -1
# Episode:  820 Total reward:  -1
# Episode:  821 Total reward:  -1
# Episode:  822 Total reward:  1
# Episode:  823 Total reward:  -5
# Episode:  824 Total reward:  1
# Episode:  825 Total reward:  -3
# Episode:  826 Total reward:  5
# Episode:  827 Total reward:  1
# Episode:  828 Total reward:  1
# Episode:  829 Total reward:  1
# Episode:  830 Total reward:  1
# Episode:  831 Total reward:  3
# Episode:  832 Total reward:  -5
# Episode:  833 Total reward:  -3
# Episode:  834 Total reward:  -1
# Episode:  835 Total reward:  -3
# Episode:  836 Total reward:  5
# Episode:  837 Total reward:  -3
# Episode:  838 Total reward:  3
# Episode:  839 Total reward:  -1
# Episode:  840 Total reward:  -3
# Episode:  841 Total reward:  1
# Episode:  842 Total reward:  -1
# Episode:  843 Total reward:  1
# Episode:  844 Total reward:  1
# Episode:  845 Total reward:  -1
# Episode:  846 Total reward:  1
# Episode:  847 Total reward:  3
# Episode:  848 Total reward:  -1
# Episode:  849 Total reward:  3
# Episode:  850 Total reward:  3
# Episode:  851 Total reward:  1
# Episode:  852 Total reward:  1
# Episode:  853 Total reward:  -5
# Episode:  854 Total reward:  1
# Episode:  855 Total reward:  1
# Episode:  856 Total reward:  -1
# Episode:  857 Total reward:  7
# Episode:  858 Total reward:  3
# Episode:  859 Total reward:  3
# Episode:  860 Total reward:  -7
# Episode:  861 Total reward:  -1
# Episode:  862 Total reward:  -3
# Episode:  863 Total reward:  -1
# Episode:  864 Total reward:  1
# Episode:  865 Total reward:  -1
# Episode:  866 Total reward:  1
# Episode:  867 Total reward:  1
# Episode:  868 Total reward:  -9
# Episode:  869 Total reward:  1
# Episode:  870 Total reward:  1
# Episode:  871 Total reward:  -3
# Episode:  872 Total reward:  3
# Episode:  873 Total reward:  1
# Episode:  874 Total reward:  -1
# Episode:  875 Total reward:  3
# Episode:  876 Total reward:  -1
# Episode:  877 Total reward:  -3
# Episode:  878 Total reward:  -3
# Episode:  879 Total reward:  -1
# Episode:  880 Total reward:  1
# Episode:  881 Total reward:  -5
# Episode:  882 Total reward:  -7
# Episode:  883 Total reward:  3
# Episode:  884 Total reward:  -1
# Episode:  885 Total reward:  -1
# Episode:  886 Total reward:  -5
# Episode:  887 Total reward:  1
# Episode:  888 Total reward:  -3
# Episode:  889 Total reward:  5
# Episode:  890 Total reward:  1
# Episode:  891 Total reward:  3
# Episode:  892 Total reward:  5
# Episode:  893 Total reward:  -1
# Episode:  894 Total reward:  -1
# Episode:  895 Total reward:  1
# Episode:  896 Total reward:  -1
# Episode:  897 Total reward:  3
# Episode:  898 Total reward:  -5
# Episode:  899 Total reward:  1
# Episode:  900 Total reward:  -1
# Episode:  901 Total reward:  -1
# Episode:  902 Total reward:  -3
# Episode:  903 Total reward:  -1
# Episode:  904 Total reward:  3
# Episode:  905 Total reward:  -1
# Episode:  906 Total reward:  -5
# Episode:  907 Total reward:  -1
# Episode:  908 Total reward:  -1
# Episode:  909 Total reward:  3
# Episode:  910 Total reward:  -3
# Episode:  911 Total reward:  1
# Episode:  912 Total reward:  1
# Episode:  913 Total reward:  1
# Episode:  914 Total reward:  1
# Episode:  915 Total reward:  -5
# Episode:  916 Total reward:  -1
# Episode:  917 Total reward:  -1
# Episode:  918 Total reward:  3
# Episode:  919 Total reward:  -1
# Episode:  920 Total reward:  1
# Episode:  921 Total reward:  -1
# Episode:  922 Total reward:  3
# Episode:  923 Total reward:  3
# Episode:  924 Total reward:  3
# Episode:  925 Total reward:  1
# Episode:  926 Total reward:  -3
# Episode:  927 Total reward:  1
# Episode:  928 Total reward:  -1
# Episode:  929 Total reward:  1
# Episode:  930 Total reward:  1
# Episode:  931 Total reward:  1
# Episode:  932 Total reward:  -1
# Episode:  933 Total reward:  1
# Episode:  934 Total reward:  1
# Episode:  935 Total reward:  1
# Episode:  936 Total reward:  -1
# Episode:  937 Total reward:  3
# Episode:  938 Total reward:  -1
# Episode:  939 Total reward:  3
# Episode:  940 Total reward:  -1
# Episode:  941 Total reward:  1
# Episode:  942 Total reward:  -1
# Episode:  943 Total reward:  5
# Episode:  944 Total reward:  -1
# Episode:  945 Total reward:  -1
# Episode:  946 Total reward:  3
# Episode:  947 Total reward:  -5
# Episode:  948 Total reward:  3
# Episode:  949 Total reward:  -1
# Episode:  950 Total reward:  -5
# Episode:  951 Total reward:  -3
# Episode:  952 Total reward:  -1
# Episode:  953 Total reward:  3
# Episode:  954 Total reward:  3
# Episode:  955 Total reward:  -3
# Episode:  956 Total reward:  1
# Episode:  957 Total reward:  -5
# Episode:  958 Total reward:  3
# Episode:  959 Total reward:  3
# Episode:  960 Total reward:  5
# Episode:  961 Total reward:  1
# Episode:  962 Total reward:  1
# Episode:  963 Total reward:  3
# Episode:  964 Total reward:  3
# Episode:  965 Total reward:  -5
# Episode:  966 Total reward:  5
# Episode:  967 Total reward:  1
# Episode:  968 Total reward:  1
# Episode:  969 Total reward:  3
# Episode:  970 Total reward:  -1
# Episode:  971 Total reward:  -3
# Episode:  972 Total reward:  7
# Episode:  973 Total reward:  -3
# Episode:  974 Total reward:  5
# Episode:  975 Total reward:  -1
# Episode:  976 Total reward:  -3
# Episode:  977 Total reward:  -1
# Episode:  978 Total reward:  1
# Episode:  979 Total reward:  -1
# Episode:  980 Total reward:  -9
# Episode:  981 Total reward:  -1
# Episode:  982 Total reward:  -3
# Episode:  983 Total reward:  5
# Episode:  984 Total reward:  -5
# Episode:  985 Total reward:  -3
# Episode:  986 Total reward:  -1
# Episode:  987 Total reward:  -1
# Episode:  988 Total reward:  1
# Episode:  989 Total reward:  1
# Episode:  990 Total reward:  1
# Episode:  991 Total reward:  -3
# Episode:  992 Total reward:  1
# Episode:  993 Total reward:  -1
# Episode:  994 Total reward:  3
# Episode:  995 Total reward:  -1
# Episode:  996 Total reward:  -1
# Episode:  997 Total reward:  1
# Episode:  998 Total reward:  -7
# Episode:  999 Total reward:  -1
# Episode:  1000 Total reward:  3
# Episode:  1001 Total reward:  -1
# Episode:  1002 Total reward:  -3
# Episode:  1003 Total reward:  1
# Episode:  1004 Total reward:  -1
# Episode:  1005 Total reward:  5
# Episode:  1006 Total reward:  3
# Episode:  1007 Total reward:  3
# Episode:  1008 Total reward:  3
# Episode:  1009 Total reward:  3
# Episode:  1010 Total reward:  -1
# Episode:  1011 Total reward:  -3
# Episode:  1012 Total reward:  1
# Episode:  1013 Total reward:  5
# Episode:  1014 Total reward:  1
# Episode:  1015 Total reward:  5
# Episode:  1016 Total reward:  -5
# Episode:  1017 Total reward:  1
# Episode:  1018 Total reward:  3
# Episode:  1019 Total reward:  1
# Episode:  1020 Total reward:  -3
# Episode:  1021 Total reward:  -1
# Episode:  1022 Total reward:  1
# Episode:  1023 Total reward:  1
# Episode:  1024 Total reward:  1
# Episode:  1025 Total reward:  -5
# Episode:  1026 Total reward:  -1
# Episode:  1027 Total reward:  -1
# Episode:  1028 Total reward:  3
# Episode:  1029 Total reward:  -3
# Episode:  1030 Total reward:  -5
# Episode:  1031 Total reward:  -3
# Episode:  1032 Total reward:  -1
# Episode:  1033 Total reward:  -1
# Episode:  1034 Total reward:  5
# Episode:  1035 Total reward:  1
# Episode:  1036 Total reward:  3
# Episode:  1037 Total reward:  -3
# Episode:  1038 Total reward:  3
# Episode:  1039 Total reward:  -3
# Episode:  1040 Total reward:  3
# Episode:  1041 Total reward:  3
# Episode:  1042 Total reward:  -5
# Episode:  1043 Total reward:  7
# Episode:  1044 Total reward:  -1
# Episode:  1045 Total reward:  -1
# Episode:  1046 Total reward:  -3
# Episode:  1047 Total reward:  -1
# Episode:  1048 Total reward:  3
# Episode:  1049 Total reward:  -3
# Episode:  1050 Total reward:  -1
# Episode:  1051 Total reward:  -3
# Episode:  1052 Total reward:  -1
# Episode:  1053 Total reward:  -1
# Episode:  1054 Total reward:  -3
# Episode:  1055 Total reward:  5
# Episode:  1056 Total reward:  1
# Episode:  1057 Total reward:  1
# Episode:  1058 Total reward:  -3
# Episode:  1059 Total reward:  1
# Episode:  1060 Total reward:  -3
# Episode:  1061 Total reward:  -5
# Episode:  1062 Total reward:  -5
# Episode:  1063 Total reward:  -1
# Episode:  1064 Total reward:  -1
# Episode:  1065 Total reward:  1
# Episode:  1066 Total reward:  -3
# Episode:  1067 Total reward:  1
# Episode:  1068 Total reward:  -3
# Episode:  1069 Total reward:  1
# Episode:  1070 Total reward:  -3
# Episode:  1071 Total reward:  -3
# Episode:  1072 Total reward:  -1
# Episode:  1073 Total reward:  3
# Episode:  1074 Total reward:  3
# Episode:  1075 Total reward:  -5
# Episode:  1076 Total reward:  -1
# Episode:  1077 Total reward:  -3
# Episode:  1078 Total reward:  1
# Episode:  1079 Total reward:  5
# Episode:  1080 Total reward:  -5
# Episode:  1081 Total reward:  1
# Episode:  1082 Total reward:  -5
# Episode:  1083 Total reward:  3
# Episode:  1084 Total reward:  1
# Episode:  1085 Total reward:  1
# Episode:  1086 Total reward:  -7
# Episode:  1087 Total reward:  3
# Episode:  1088 Total reward:  -3
# Episode:  1089 Total reward:  -3
# Episode:  1090 Total reward:  1
# Episode:  1091 Total reward:  1
# Episode:  1092 Total reward:  -7
# Episode:  1093 Total reward:  -1
# Episode:  1094 Total reward:  1
# Episode:  1095 Total reward:  3
# Episode:  1096 Total reward:  1
# Episode:  1097 Total reward:  -3
# Episode:  1098 Total reward:  1
# Episode:  1099 Total reward:  -1
# Episode:  1100 Total reward:  3
# Episode:  1101 Total reward:  -5
# Episode:  1102 Total reward:  1
# Episode:  1103 Total reward:  -1
# Episode:  1104 Total reward:  -1
# Episode:  1105 Total reward:  3
# Episode:  1106 Total reward:  -1
# Episode:  1107 Total reward:  5
# Episode:  1108 Total reward:  -1
# Episode:  1109 Total reward:  -3
# Episode:  1110 Total reward:  3
# Episode:  1111 Total reward:  1
# Episode:  1112 Total reward:  5
# Episode:  1113 Total reward:  -1
# Episode:  1114 Total reward:  -7
# Episode:  1115 Total reward:  -3
# Episode:  1116 Total reward:  -5
# Episode:  1117 Total reward:  3
# Episode:  1118 Total reward:  -1
# Episode:  1119 Total reward:  -1
# Episode:  1120 Total reward:  5
# Episode:  1121 Total reward:  1
# Episode:  1122 Total reward:  1
# Episode:  1123 Total reward:  1
# Episode:  1124 Total reward:  -1
# Episode:  1125 Total reward:  1
# Episode:  1126 Total reward:  -5
# Episode:  1127 Total reward:  -3
# Episode:  1128 Total reward:  1
# Episode:  1129 Total reward:  -1
# Episode:  1130 Total reward:  1
# Episode:  1131 Total reward:  1
# Episode:  1132 Total reward:  1
# Episode:  1133 Total reward:  1
# Episode:  1134 Total reward:  1
# Episode:  1135 Total reward:  -1
# Episode:  1136 Total reward:  3
# Episode:  1137 Total reward:  -3
# Episode:  1138 Total reward:  3
# Episode:  1139 Total reward:  -3
# Episode:  1140 Total reward:  -1
# Episode:  1141 Total reward:  1
# Episode:  1142 Total reward:  1
# Episode:  1143 Total reward:  -9
# Episode:  1144 Total reward:  1
# Episode:  1145 Total reward:  1
# Episode:  1146 Total reward:  1
# Episode:  1147 Total reward:  3
# Episode:  1148 Total reward:  -3
# Episode:  1149 Total reward:  -1
# Episode:  1150 Total reward:  1
# Episode:  1151 Total reward:  5
# Episode:  1152 Total reward:  3
# Episode:  1153 Total reward:  -3
# Episode:  1154 Total reward:  1
# Episode:  1155 Total reward:  1
# Episode:  1156 Total reward:  -1
# Episode:  1157 Total reward:  1
# Episode:  1158 Total reward:  1
# Episode:  1159 Total reward:  -3
# Episode:  1160 Total reward:  -5
# Episode:  1161 Total reward:  -1
# Episode:  1162 Total reward:  1
# Episode:  1163 Total reward:  3
# Episode:  1164 Total reward:  -1
# Episode:  1165 Total reward:  -1
# Episode:  1166 Total reward:  -3
# Episode:  1167 Total reward:  1
# Episode:  1168 Total reward:  1
# Episode:  1169 Total reward:  -1
# Episode:  1170 Total reward:  -1
# Episode:  1171 Total reward:  -1
# Episode:  1172 Total reward:  -3
# Episode:  1173 Total reward:  1
# Episode:  1174 Total reward:  3
# Episode:  1175 Total reward:  3
# Episode:  1176 Total reward:  -3
# Episode:  1177 Total reward:  1
# Episode:  1178 Total reward:  1
# Episode:  1179 Total reward:  -5
# Episode:  1180 Total reward:  1
# Episode:  1181 Total reward:  3
# Episode:  1182 Total reward:  -3
# Episode:  1183 Total reward:  -3
# Episode:  1184 Total reward:  1
# Episode:  1185 Total reward:  1
# Episode:  1186 Total reward:  1
# Episode:  1187 Total reward:  -1
# Episode:  1188 Total reward:  1
# Episode:  1189 Total reward:  3
# Episode:  1190 Total reward:  -1
# Episode:  1191 Total reward:  -5
# Episode:  1192 Total reward:  1
# Episode:  1193 Total reward:  1
# Episode:  1194 Total reward:  3
# Episode:  1195 Total reward:  -1
# Episode:  1196 Total reward:  -7
# Episode:  1197 Total reward:  5
# Episode:  1198 Total reward:  1
# Episode:  1199 Total reward:  3
# Episode:  1200 Total reward:  -1
# Episode:  1201 Total reward:  -7
# Episode:  1202 Total reward:  -1
# Episode:  1203 Total reward:  5
# Episode:  1204 Total reward:  -3
# Episode:  1205 Total reward:  -3
# Episode:  1206 Total reward:  5
# Episode:  1207 Total reward:  1
# Episode:  1208 Total reward:  -3
# Episode:  1209 Total reward:  -1
# Episode:  1210 Total reward:  1
# Episode:  1211 Total reward:  5
# Episode:  1212 Total reward:  3
# Episode:  1213 Total reward:  5
# Episode:  1214 Total reward:  -3
# Episode:  1215 Total reward:  -3
# Episode:  1216 Total reward:  1
# Episode:  1217 Total reward:  3
# Episode:  1218 Total reward:  3
# Episode:  1219 Total reward:  -1
# Episode:  1220 Total reward:  -3
# Episode:  1221 Total reward:  1
# Episode:  1222 Total reward:  3
# Episode:  1223 Total reward:  1
# Episode:  1224 Total reward:  -3
# Episode:  1225 Total reward:  -5
# Episode:  1226 Total reward:  -1
# Episode:  1227 Total reward:  3
# Episode:  1228 Total reward:  -5
# Episode:  1229 Total reward:  3
# Episode:  1230 Total reward:  1
# Episode:  1231 Total reward:  -7
# Episode:  1232 Total reward:  -1
# Episode:  1233 Total reward:  -3
# Episode:  1234 Total reward:  -1
# Episode:  1235 Total reward:  -1
# Episode:  1236 Total reward:  1
# Episode:  1237 Total reward:  -3
# Episode:  1238 Total reward:  -1
# Episode:  1239 Total reward:  1
# Episode:  1240 Total reward:  3
# Episode:  1241 Total reward:  5
# Episode:  1242 Total reward:  1
# Episode:  1243 Total reward:  1
# Episode:  1244 Total reward:  1
# Episode:  1245 Total reward:  -1
# Episode:  1246 Total reward:  -1
# Episode:  1247 Total reward:  -5
# Episode:  1248 Total reward:  1
# Episode:  1249 Total reward:  -1
# Episode:  1250 Total reward:  1
# Episode:  1251 Total reward:  1
# Episode:  1252 Total reward:  -3
# Episode:  1253 Total reward:  3
# Episode:  1254 Total reward:  5
# Episode:  1255 Total reward:  1
# Episode:  1256 Total reward:  -1
# Episode:  1257 Total reward:  -1
# Episode:  1258 Total reward:  -3
# Episode:  1259 Total reward:  1
# Episode:  1260 Total reward:  5
# Episode:  1261 Total reward:  -3
# Episode:  1262 Total reward:  1
# Episode:  1263 Total reward:  -3
# Episode:  1264 Total reward:  3
# Episode:  1265 Total reward:  1
# Episode:  1266 Total reward:  1
# Episode:  1267 Total reward:  5
# Episode:  1268 Total reward:  3
# Episode:  1269 Total reward:  -3
# Episode:  1270 Total reward:  1
# Episode:  1271 Total reward:  -3
# Episode:  1272 Total reward:  -1
# Episode:  1273 Total reward:  -1
# Episode:  1274 Total reward:  1
# Episode:  1275 Total reward:  -3
# Episode:  1276 Total reward:  -1
# Episode:  1277 Total reward:  3
# Episode:  1278 Total reward:  -3
# Episode:  1279 Total reward:  1
# Episode:  1280 Total reward:  3
# Episode:  1281 Total reward:  3
# Episode:  1282 Total reward:  1
# Episode:  1283 Total reward:  -3
# Episode:  1284 Total reward:  1
# Episode:  1285 Total reward:  -1
# Episode:  1286 Total reward:  3
# Episode:  1287 Total reward:  3
# Episode:  1288 Total reward:  1
# Episode:  1289 Total reward:  3
# Episode:  1290 Total reward:  1
# Episode:  1291 Total reward:  5
# Episode:  1292 Total reward:  -3
# Episode:  1293 Total reward:  1
# Episode:  1294 Total reward:  3
# Episode:  1295 Total reward:  -1
# Episode:  1296 Total reward:  3
# Episode:  1297 Total reward:  1
# Episode:  1298 Total reward:  1
# Episode:  1299 Total reward:  3
# Episode:  1300 Total reward:  -3
# Episode:  1301 Total reward:  1
# Episode:  1302 Total reward:  -1
# Episode:  1303 Total reward:  1
# Episode:  1304 Total reward:  -1
# Episode:  1305 Total reward:  1
# Episode:  1306 Total reward:  1
# Episode:  1307 Total reward:  1
# Episode:  1308 Total reward:  -1
# Episode:  1309 Total reward:  -3
# Episode:  1310 Total reward:  3
# Episode:  1311 Total reward:  3
# Episode:  1312 Total reward:  -1
# Episode:  1313 Total reward:  -5
# Episode:  1314 Total reward:  1
# Episode:  1315 Total reward:  -5
# Episode:  1316 Total reward:  -1
# Episode:  1317 Total reward:  1
# Episode:  1318 Total reward:  -3
# Episode:  1319 Total reward:  7
# Episode:  1320 Total reward:  3
# Episode:  1321 Total reward:  -3
# Episode:  1322 Total reward:  -1
# Episode:  1323 Total reward:  3
# Episode:  1324 Total reward:  -3
# Episode:  1325 Total reward:  3
# Episode:  1326 Total reward:  -3
# Episode:  1327 Total reward:  -3
# Episode:  1328 Total reward:  3
# Episode:  1329 Total reward:  3
# Episode:  1330 Total reward:  3
# Episode:  1331 Total reward:  3
# Episode:  1332 Total reward:  1
# Episode:  1333 Total reward:  1
# Episode:  1334 Total reward:  1
# Episode:  1335 Total reward:  -3
# Episode:  1336 Total reward:  5
# Episode:  1337 Total reward:  -1
# Episode:  1338 Total reward:  -1
# Episode:  1339 Total reward:  -3
# Episode:  1340 Total reward:  -1
# Episode:  1341 Total reward:  -3
# Episode:  1342 Total reward:  1
# Episode:  1343 Total reward:  3
# Episode:  1344 Total reward:  -3
# Episode:  1345 Total reward:  3
# Episode:  1346 Total reward:  -5
# Episode:  1347 Total reward:  3
# Episode:  1348 Total reward:  -5
# Episode:  1349 Total reward:  1
# Episode:  1350 Total reward:  -5
# Episode:  1351 Total reward:  -3
# Episode:  1352 Total reward:  -1
# Episode:  1353 Total reward:  5
# Episode:  1354 Total reward:  1
# Episode:  1355 Total reward:  1
# Episode:  1356 Total reward:  -3
# Episode:  1357 Total reward:  3
# Episode:  1358 Total reward:  -3
# Episode:  1359 Total reward:  -1
# Episode:  1360 Total reward:  3
# Episode:  1361 Total reward:  1
# Episode:  1362 Total reward:  -1
# Episode:  1363 Total reward:  7
# Episode:  1364 Total reward:  -3
# Episode:  1365 Total reward:  3
# Episode:  1366 Total reward:  -1
# Episode:  1367 Total reward:  5
# Episode:  1368 Total reward:  1
# Episode:  1369 Total reward:  1
# Episode:  1370 Total reward:  -1
# Episode:  1371 Total reward:  -3
# Episode:  1372 Total reward:  1
# Episode:  1373 Total reward:  -1
# Episode:  1374 Total reward:  1
# Episode:  1375 Total reward:  1
# Episode:  1376 Total reward:  -3
# Episode:  1377 Total reward:  3
# Episode:  1378 Total reward:  -1
# Episode:  1379 Total reward:  -1
# Episode:  1380 Total reward:  1
# Episode:  1381 Total reward:  -1
# Episode:  1382 Total reward:  3
# Episode:  1383 Total reward:  -5
# Episode:  1384 Total reward:  -3
# Episode:  1385 Total reward:  3
# Episode:  1386 Total reward:  -7
# Episode:  1387 Total reward:  1
# Episode:  1388 Total reward:  1
# Episode:  1389 Total reward:  1
# Episode:  1390 Total reward:  -7
# Episode:  1391 Total reward:  5
# Episode:  1392 Total reward:  3
# Episode:  1393 Total reward:  3
# Episode:  1394 Total reward:  -3
# Episode:  1395 Total reward:  -3
# Episode:  1396 Total reward:  -1
# Episode:  1397 Total reward:  -3
# Episode:  1398 Total reward:  -3
# Episode:  1399 Total reward:  1
# Episode:  1400 Total reward:  -1
# Episode:  1401 Total reward:  5
# Episode:  1402 Total reward:  3
# Episode:  1403 Total reward:  1
# Episode:  1404 Total reward:  1
# Episode:  1405 Total reward:  1
# Episode:  1406 Total reward:  5
# Episode:  1407 Total reward:  -5
# Episode:  1408 Total reward:  -3
# Episode:  1409 Total reward:  -3
# Episode:  1410 Total reward:  5
# Episode:  1411 Total reward:  1
# Episode:  1412 Total reward:  1
# Episode:  1413 Total reward:  -1
# Episode:  1414 Total reward:  -1
# Episode:  1415 Total reward:  -1
# Episode:  1416 Total reward:  -1
# Episode:  1417 Total reward:  1
# Episode:  1418 Total reward:  7
# Episode:  1419 Total reward:  -1
# Episode:  1420 Total reward:  -5
# Episode:  1421 Total reward:  -1
# Episode:  1422 Total reward:  3
# Episode:  1423 Total reward:  1
# Episode:  1424 Total reward:  3
# Episode:  1425 Total reward:  -1
# Episode:  1426 Total reward:  -1
# Episode:  1427 Total reward:  -1
# Episode:  1428 Total reward:  5
# Episode:  1429 Total reward:  7
# Episode:  1430 Total reward:  -3
# Episode:  1431 Total reward:  3
# Episode:  1432 Total reward:  1
# Episode:  1433 Total reward:  -3
# Episode:  1434 Total reward:  -5
# Episode:  1435 Total reward:  1
# Episode:  1436 Total reward:  1
# Episode:  1437 Total reward:  1
# Episode:  1438 Total reward:  5
# Episode:  1439 Total reward:  3
# Episode:  1440 Total reward:  -1
# Episode:  1441 Total reward:  7
# Episode:  1442 Total reward:  1
# Episode:  1443 Total reward:  -3
# Episode:  1444 Total reward:  -5
# Episode:  1445 Total reward:  1
# Episode:  1446 Total reward:  1
# Episode:  1447 Total reward:  -1
# Episode:  1448 Total reward:  1
# Episode:  1449 Total reward:  5
# Episode:  1450 Total reward:  3
# Episode:  1451 Total reward:  -5
# Episode:  1452 Total reward:  -1
# Episode:  1453 Total reward:  -1
# Episode:  1454 Total reward:  -3
# Episode:  1455 Total reward:  1
# Episode:  1456 Total reward:  3
# Episode:  1457 Total reward:  -1
# Episode:  1458 Total reward:  -3
# Episode:  1459 Total reward:  -1
# Episode:  1460 Total reward:  -3
# Episode:  1461 Total reward:  -1
# Episode:  1462 Total reward:  -3
# Episode:  1463 Total reward:  -3
# Episode:  1464 Total reward:  -3
# Episode:  1465 Total reward:  1
# Episode:  1466 Total reward:  -1
# Episode:  1467 Total reward:  -1
# Episode:  1468 Total reward:  -1
# Episode:  1469 Total reward:  1
# Episode:  1470 Total reward:  -1
# Episode:  1471 Total reward:  -1
# Episode:  1472 Total reward:  3
# Episode:  1473 Total reward:  1
# Episode:  1474 Total reward:  1
# Episode:  1475 Total reward:  -3
# Episode:  1476 Total reward:  -5
# Episode:  1477 Total reward:  -3
# Episode:  1478 Total reward:  1
# Episode:  1479 Total reward:  1
# Episode:  1480 Total reward:  1
# Episode:  1481 Total reward:  3
# Episode:  1482 Total reward:  1
# Episode:  1483 Total reward:  3
# Episode:  1484 Total reward:  3
# Episode:  1485 Total reward:  -3
# Episode:  1486 Total reward:  1
# Episode:  1487 Total reward:  -3
# Episode:  1488 Total reward:  -3
# Episode:  1489 Total reward:  3
# Episode:  1490 Total reward:  3
# Episode:  1491 Total reward:  -1
# Episode:  1492 Total reward:  -1
# Episode:  1493 Total reward:  1
# Episode:  1494 Total reward:  3
# Episode:  1495 Total reward:  1
# Episode:  1496 Total reward:  5
# Episode:  1497 Total reward:  -1
# Episode:  1498 Total reward:  3
# Episode:  1499 Total reward:  5

# %% [markdown]
# #### Visualize $\epsilon$
# Plot our value of $\epsilon$ over each episode

# %%
plt.xlabel('Episode')
plt.ylabel('$\epsilon$')
plt.plot(epsilons)

# %% [markdown]
# #### Visualize Rewards
# Plot total_rewards per episode.  We apply a rolling mean of window $10$ to visualize easier.

# %%
window = 10
plt.xlabel('Episode')
plt.ylabel('Total Reward (SMA 10)')
plt.plot([np.mean(total_rewards[tr:tr+window]) for tr in range(window, len(total_rewards))])

# %%
env = GridEnvironment()

obs = env.reset()
done = False
agent.epsilon = 0
env.render()
plt.show()

while not done:
    action = agent.step(obs)
    obs, reward, done, info = env.step(action)
    env.render()
    plt.show()

# %%
print(agent.q_table)
# down, up, right, left
# Out:
# [[[ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15383699  1.15384615 -1.15383699]
#   [ 1.15384615 -0.888       1.13973393 -1.0925952 ]
#   [ 1.1505947  -1.0925952   0.         -1.1244457 ]]
#
#  [[ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384567  1.15382707 -1.15384592]
#   [ 1.13973393 -1.1244457   1.15384615 -1.1244457 ]
#   [ 1.15384615 -1.15309702 -1.15309702 -1.14707229]]
#
#  [[ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384615  1.15384615 -1.15384615]
#   [ 1.15384615 -1.15384615 -1.15384404 -1.15384615]]
#
#  [[ 1.15384615 -1.0925952   1.13973393 -1.1244457 ]
#   [ 1.15384615 -1.14707229  1.1244457  -1.14707229]
#   [ 1.15384615 -1.15383699  1.14707229 -1.14707229]
#   [ 1.15384615 -1.13973393  1.02624     0.        ]
#   [ 1.15384615 -1.15367355 -1.15380639 -1.15348657]]
#
#  [[-1.0925952  -0.888       1.15384614 -0.888     ]
#   [-1.13973393 -1.1244457   1.15384615 -1.02624   ]
#   [-1.15376331 -1.14707229  1.15384615 -1.1505947 ]
#   [-1.15309702 -1.15367355  1.15384615 -1.14707229]
#   [ 0.          0.          0.          0.        ]]]
